# %%
print("hello world")
# Out:
# hello world

# %%
print(45)
# Out:
# 45

# %%
print(20*5)
# <-- is used for comments.
# we can use ctrl+/ to comment selected part.
# Out:
# 100

# %%
print("parth","08", 0o0, 8)
#08 ko direct print nahi kar skte due to SyntaxError: leading zeros in decimal integer literals are not permitted; use an 0o prefix for octal integers[0-7].
# Out:
# parth 08 0 8

# %%
print("hello \nhello again")
# Out:
# hello
# hello again

# %%
'''this is used for multiline 
comment in .py file, also we use -""" """  '''#this gets printed as we are in pynotebook(.ipynb) if any print statement is mentioned it wont be printed and be a comment.
# Out:
# 'this is used for multiline \ncomment in .py file, also we use -""" """  '

# %%
print("helllo",7,8,sep="~",end="\nbye")#sep can also be used to remove space from the output by sep=""
# Out:
# helllo~7~8
# bye

# %%
a=[1,2,34,5]
for i in a:
    print(i,end=" ")#here end parameter is used to print output in single line with space in between.

print("\n")

    #or to print in different line
for i in a:
    print(i)#this method allways create a new line
# Out:
# 1 2 34 5
#
# 1
# 2
# 34
# 5

# %%
# %pip install pandas
#pip is the installaton comand, used to download external librarys.
#old cpmand was !pip install
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
